# %%
import biojs
from jsobject import JSObject
# Out:
# javascript loaded
# msa
# fasta

# %%
window = JSObject()
console = window.console
console.log('jsobject running')
# Out:
# javascript loaded
# jsobject running

# %%
m = window.msa()

# %%
console.log(m)

# %%
m.u.file.importURL("http://rostlab.org/~goldberg/jalv_example.clustal")
# Out:
# http://rostlab.org/~goldberg/jalv_example.clustal

# %%
m.render()
